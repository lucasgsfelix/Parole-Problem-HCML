# %% [markdown]
# # Join and Pre-Process the New York City Datasets
#
# Code responsible to Join and Pre-Process three New York City datasets:
#
# - Crimes
# - Census
# - Housing

# %%
import math
import pandas as pd

# %%
df_census = pd.read_table("Input/census_data.csv", sep = ',')
df_crimes = pd.read_table("Input/crimes_data.csv", sep = ',')
df_housing = pd.read_table("Input/housing_data.csv", sep = ',')

# %% [markdown]
# ### Auxiliary Function: Rename Columns

# %%
def rename_columns(df, string):
    
    new_columns = list(map(lambda x: {x: x + ' ' + string}, df.columns))
    columns = {}
    for index, column in enumerate(new_columns):
        key = list(column.keys())[0]
        columns[key] = new_columns[index][key]

    return columns

# %%
columns = rename_columns(df_crimes, 'Crimes')
df_crimes.rename(columns = columns, inplace = True)
df_crimes.head(5)
# Out:
#   Event Date Crimes Event Ending Date Crimes Event Report Date Crimes  \
# 0        12/31/2015                      NaN               12/31/2015
# 1        12/31/2015                      NaN               12/31/2015
# 2        12/31/2015                      NaN               12/31/2015
# 3        12/31/2015                      NaN               12/31/2015
# 4        12/31/2015               12/31/2015               12/31/2015
#
#                 Description Crimes Attempt Complete Crimes  \
# 0                          FORGERY               COMPLETED
# 1  MURDER & NON-NEGL. MANSLAUGHTER               COMPLETED
# 2                  DANGEROUS DRUGS               COMPLETED
# 3     ASSAULT 3 & RELATED OFFENSES               COMPLETED
# 4     ASSAULT 3 & RELATED OFFENSES               COMPLETED
#
#   Level of Offense Crimes Borough Crimes  Latitude Crimes  Longitude Crimes
# 0                  FELONY          BRONX        40.828848        -73.916661
# 1                  FELONY         QUEENS        40.697338        -73.784557
# 2                  FELONY      MANHATTAN        40.802607        -73.945052
# 3             MISDEMEANOR         QUEENS        40.654549        -73.726339
# 4             MISDEMEANOR      MANHATTAN        40.738002        -73.987891

# %%
columns = rename_columns(df_census, 'Census')
df_census.rename(columns = columns, inplace = True)
df_census.head(5)
# Out:
#    BlockCode Census  Latitude Census  Longitude Census County Census  \
# 0       36005000100        40.792756        -73.883541         BRONX
# 1       36005000200        40.805866        -73.860278         BRONX
# 2       36005000400        40.807594        -73.851237         BRONX
# 3       36005001600        40.819196        -73.858040         BRONX
# 4       36005001900        40.801216        -73.909212         BRONX
#
#   Borough Census  TotalPop Census  Men Census  Women Census  Hispanic Census  \
# 0          BRONX             7703        7133           570             29.9
# 1          BRONX             5403        2659          2744             75.8
# 2          BRONX             5915        2896          3019             62.7
# 3          BRONX             5879        2558          3321             65.1
# 4          BRONX             2591        1206          1385             55.4
#
#    White Census         ...           Walk Census  OtherTransp Census  \
# 0           6.1         ...                   NaN                 NaN
# 1           2.3         ...                   2.9                 0.0
# 2           3.6         ...                   1.4                 0.5
# 3           1.6         ...                   8.6                 1.6
# 4           9.0         ...                   3.0                 2.4
#
#    WorkAtHome Census  MeanCommute Census  Employed Census  PrivateWork Census  \
# 0                NaN                 NaN                0                 NaN
# 1                0.0                43.0             2308                80.8
# 2                2.1                45.0             2675                71.7
# 3                1.7                38.8             2120                75.0
# 4                6.2                45.4             1083                76.8
#
#    PublicWork Census  SelfEmployed Census  FamilyWork Census  \
# 0                NaN                  NaN                NaN
# 1               16.2                  2.9                0.0
# 2               25.3                  2.5                0.6
# 3               21.3                  3.8                0.0
# 4               15.5                  7.7                0.0
#
#    Unemployment Census
# 0                  NaN
# 1                  7.7
# 2                  9.5
# 3                  8.7
# 4                 19.2
#
# [5 rows x 38 columns]

# %%
df_housing.head(5)
# Out:
#      Borough   Latitude  Longitude  Extremely Low Income Units  \
# 0  MANHATTAN  40.811202 -73.942995                           0
# 1  MANHATTAN  40.833829 -73.941339                          20
# 2  MANHATTAN  40.835160 -73.941663                           6
# 3  MANHATTAN  40.835295 -73.941977                           4
# 4   BROOKLYN  40.708637 -73.948486                          59
#
#    Very Low Income Units  Low Income Units  Moderate Income Units  \
# 0                     16                24                      0
# 1                      3                 1                      0
# 2                     11                 3                      0
# 3                     14                 2                      0
# 4                      7                 4                      0
#
#    Middle Income Units  Other Income Units  Studio Units  Mean Bathrooms  \
# 0                   38                   1            16        1.354430
# 1                    0                   1             0        2.600000
# 2                    0                   0             0        2.000000
# 3                    0                   0             0        2.000000
# 4                    0                   1             0        2.197183
#
#      County
# 0  NEW YORK
# 1  NEW YORK
# 2  NEW YORK
# 3  NEW YORK
# 4     KINGS

# %% [markdown]
# ### Defining distance between two geographic points

# %% [markdown]
# Given 2 points of latitude and longitude:
#
# $
#     \DeclareMathOperator{\atantwo}{atan2}
#     earth\_radius = 6373.0 \\
#     dist\_lat = lat_b -  lat_a \\
#     dist\_lon = lon_b - lon_a \\
#     a = \sin(\frac{dist\_lat}{2})^2+ cos(lat_a) \times \cos(lat_b) \times \sin(\frac{dist\_lon}{2})^2 \\
#     b = 2 \times \atantwo(\sqrt(a), \sqrt(1-a)) \\
#     distance = earth\_radius \times b \\
# $

# %%
def geo_point_distance(lat_a, long_a, lat_b, long_b):
    # approximate radius of earth in km
    earth_radius = 6373.0
    point_a, point_b = {}, {}

    point_a['Lat'] = math.radians(lat_a)
    point_a['Long'] = math.radians(long_a)
    
    point_b['Lat'] = math.radians(lat_b)
    point_b['Long'] = math.radians(long_b)

    distance_lon = point_b['Long'] - point_a['Long']
    distance_lat = point_b['Lat'] - point_a['Lat']
    
    a = math.cos(point_b['Lat'])*math.sin(distance_lon / 2)**2
    a = math.sin(distance_lat/2)**2+math.cos(point_a['Lat'])*a
    a = 2 * math.atan2(math.sqrt(a), math.sqrt(1 - a))

    distance = earth_radius * a

    return distance

# %% [markdown]
# ### Measuring geopoint distances

# %%
def measure_geopoint(df_one, df_two, geo_string):

    index = 0
    for census_lat, census_long in zip(df_one['Latitude'], df_one['Longitude']):

            # distance between a block and a crime
            values = list(map(lambda x, y: geo_point_distance(census_lat, census_long, x, y),
                              df_two['Latitude ' + geo_string], df_two['Longitude ' + geo_string]))

            min_value_index = values.index(min(values))

            for column in df_two.columns:
                df_one.loc[index, column] = df_two.loc[min_value_index, column]
            df_one.loc[index,  geo_string + ' Distance'] = min(values)

            index+=1
    
    return df_one

# %%
df_housing = measure_geopoint(df_housing, df_crimes, 'Crimes')

# %%
df = measure_geopoint(df_housing, df_census, 'Census')

# %%
df_census.head(5)
# Out:
#      BlockCode   Latitude  Longitude County Borough  TotalPop   Men  Women  \
# 0  36005000100  40.792756 -73.883541  BRONX   BRONX      7703  7133    570
# 1  36005000200  40.805866 -73.860278  BRONX   BRONX      5403  2659   2744
# 2  36005000400  40.807594 -73.851237  BRONX   BRONX      5915  2896   3019
# 3  36005001600  40.819196 -73.858040  BRONX   BRONX      5879  2558   3321
# 4  36005001900  40.801216 -73.909212  BRONX   BRONX      2591  1206   1385
#
#    Hispanic  White        ...         Extremely Low Income Units Housing  \
# 0      29.9    6.1        ...                                        0.0
# 1      75.8    2.3        ...                                        4.0
# 2      62.7    3.6        ...                                        0.0
# 3      65.1    1.6        ...                                        0.0
# 4      55.4    9.0        ...                                       17.0
#
#    Very Low Income Units Housing  Low Income Units Housing  \
# 0                            0.0                      17.0
# 1                           17.0                      26.0
# 2                           31.0                       0.0
# 3                           39.0                       0.0
# 4                            2.0                      15.0
#
#    Moderate Income Units Housing  Middle Income Units Housing  \
# 0                           66.0                          0.0
# 1                           12.0                          0.0
# 2                            0.0                          0.0
# 3                            0.0                          0.0
# 4                            0.0                          0.0
#
#    Other Income Units Housing  Studio Units Housing  Mean Bathrooms Housing  \
# 0                         1.0                  12.0                1.357143
# 1                         0.0                   0.0                1.000000
# 2                         0.0                   0.0                1.000000
# 3                         0.0                   0.0                2.564103
# 4                         0.0                   0.0                2.235294
#
#    County Housing  Housing Distance
# 0          QUEENS          2.275122
# 1           BRONX          1.047753
# 2           BRONX          1.375001
# 3           BRONX          0.196547
# 4           BRONX          0.572929
#
# [5 rows x 51 columns]

# %%
df.to_csv("teste.csv", sep = ',', index = False)
